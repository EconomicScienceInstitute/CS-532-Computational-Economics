# %% [markdown]
# # FCC Auction Bid Optimization
#
# The FCC often auctions off licenses to use radio spectrum in frequency chunks that are called blocks. They have mapped out 416 geographical regions call Partial Economic Areas (PEA), each of which have a set number of licenses available in the auction.  For this example, there are 411 PEAs and each have 24 licenses available.  The licenses are named M1 through M10 and N1 through N14 and their frequencies are all contiguous in that order. The data file provided lists each PEA and it's population per MHz of spectrum (MHzPOPs) for each license.  The greater the MHzPOPs the more potential customers that can be served by a license in that PEA.  The ultimate goal of participating in this auction is to maximize the MHzPOPs of the licenses won in the auction.  The data file also lists the price for each license, which varies significantly between licenses.  You must decide which licenses to buy with some restrictions.  First, you have a total budget of $100 million to spend. Next, you want to win at most 4 licenses in any single PEA but require at least 2 licenses for the spectrum to be useful to you.  Finally, you can only buy licenses that are contiguous (i.e. next to each other).
#
# ## (COLAB ONLY) Install OR-tools

# %%
# !pip install ortools
# Out:
# Collecting ortools
#   Downloading ortools-9.1.9490-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 6.7 MB/s
# Collecting absl-py>=0.13
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 37.9 MB/s
# Collecting protobuf>=3.18.0
#   Downloading protobuf-3.19.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 36.5 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.13->ortools) (1.15.0)
# Installing collected packages: protobuf, absl-py, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.12.0
#     Uninstalling absl-py-0.12.0:
#       Successfully uninstalled absl-py-0.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.4.0 requires absl-py<0.13,>=0.9, but you have absl-py 1.0.0 which is incompatible.
# Successfully installed absl-py-1.0.0 ortools-9.1.9490 protobuf-3.19.1

# %% [markdown]
# ## Import our 3rd party libraries

# %%
from ortools.linear_solver import pywraplp
import pandas as pd

# %% [markdown]
# ## Import our data file using pandas
#
# Remember, the data file has some valuable information in it.  It lists the maximum licenses we would like to win in each PEA (happens to be constant at 4).  It also lists the MHzPOPs for each PEA which is necessary for our objective function.  Finally, it also has the price of each license.

# %%
data = pd.read_csv('values.csv')

# %% [markdown]
# ## Create our solver
#
# Even though we have not yet talked about the linear programming model we are building we know that it is going to be an Integer Programming problem because we are selecting some subset of fixed things (licenses).  Therefore we create an or-tools solver using SCIP which is an integer programming library.

# %%
solver = pywraplp.Solver.CreateSolver('SCIP')

# %% [markdown]
# ## Define Variables
#
# Now we need to start defining our model.  I always recommend doing this by hand first on paper or a whiteboard.  After you have it all mapped out, then you can program it.  The way you define it in or-tools is very very similar to how you write it out by hand.
#
# Since our goal is to choose which licenses are optimal to select from some group of available licenses, we would naturally think to use binary variables to represent if a license is optimal to select.  However, looking a little further down the line we know that if we choose multiple licenses in a PEA they must all be contiguous.  This may be possible with these variables and some smart constrains but I propose a different solution.  To me, it make more sense to create a variable that represents a number of contiguous licenses.  Here is what the licenses for a single PEA look like:
#
# |M1|M2|...|M10|N1|N2|...|N14|
# | --- | --- | --- | --- | --- | --- | --- | --- |
#
# If you want 3 licenses, you would have (24 - 3 + 1 =) 22 variables that would represent the following assignments:
#
# |License 1| License 2| License 3|
# | --- | --- | --- |
# |M1|M2|M3|
# |M2|M3|M4|
# |M3|M4|M5|
# |...|...|...|
# |N12|N13|N14|
#
# However, since our demand is not fixed, we would also need to create these variables for the possibility of 2 and 4 license combinations.  Therefore, we want to iterate through each PEA and create a variable that represents 4, 3, and 2 contiguous licenses along with storing the cost and MHzPOPs for that assignment.

# %%
cost = {}
mhz_pop = {}
assignments = {}

for row in range(len(data)):
  for blocks in range(2, data['Demand'][row] + 1):
    for index in range(24 - blocks + 1):
      key = (data['PEA'][row],blocks,index)
      assignments[key] = solver.IntVar(0,1,str(key))
      # since our data has 5 columns before the license prices start we need to shift our indexing by 5
      cost[key] = sum(data.iloc[row][(5 + index):(5 + index + blocks)])
      mhz_pop[key] = data['MHzPOPs'][row] * blocks

# %% [markdown]
# ## Create objective function
#
# Now that we have created our variables, we can define our objective function.  To reiterate, our objective is to maximize MHzPOPs.

# %%
solver.Maximize(sum([mhz_pop[key] * key[1] * assignments[key] for key in assignments.keys()]))

# %% [markdown]
# ## Add constraints
#
# Our only real constraints here is our budget and that we do not want to win more than one assignment per PEA.
#
# ### Budget Constraint

# %%
solver.Add(sum([cost[(pea, blocks, index)] * assignments[(pea, blocks, index)] for pea in data['PEA'] for blocks in range(2,5) for index in range(24 - blocks + 1)]) <= 100000000)
# Out:
# <ortools.linear_solver.pywraplp.Constraint; proxy of <Swig Object of type 'operations_research::MPConstraint *' at 0x0000026E0BD3DC30> >

# %% [markdown]
# ### Single assignment constraints
#
# Notice this is a loop that creates a constraint per PEA, so it is multiple constraints.  Each of these constraints says that we want at most 1 assignment per PEA.

# %%
for pea in data['PEA']:
    solver.Add(sum([assignments[(pea, blocks, index)] for blocks in range(2,5) for index in range(24 - blocks + 1)]) <= 1)

# %% [markdown]
# ## Solve
#
# Now all we need to do is solve and check that the result is optimal.  If it is we should print our results.

# %%
status = solver.Solve()

licenses = ['M' + str(i + 1) for i in range(10)] + ['N' + str(i + 1) for i in range(14)]

if status == pywraplp.Solver.OPTIMAL:
    print('Solution:')
    print('Total MHzPOPs =', solver.Objective().Value())
    print('Licenses Won:')
    spending = 0
    for pea in data['PEA']:
        for blocks in range(2,5):
            for index in range(24 - blocks + 1):
                key = (pea, blocks, index)
                if assignments[key].solution_value() == 1:
                    spending += cost[(pea, blocks, index)]
                    message = str(key) + " " + pea + ': won ' + str(blocks) + ' licenses ' + str(licenses[index:(index + blocks)])
                    print(message)
    print(f'Total Spent = {spending}')
else:
    print('The problem does not have an optimal solution.')
# Out:
# Solution:
# Total MHzPOPs = 375775751700.0
# Licenses Won:
# ('PEA001', 2, 4) PEA001: won 2 licenses ['M5', 'M6']
# ('PEA004', 4, 14) PEA004: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA005', 4, 1) PEA005: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA006', 4, 19) PEA006: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA007', 2, 17) PEA007: won 2 licenses ['N8', 'N9']
# ('PEA008', 4, 10) PEA008: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA009', 4, 20) PEA009: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA011', 3, 4) PEA011: won 3 licenses ['M5', 'M6', 'M7']
# ('PEA012', 4, 1) PEA012: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA013', 4, 0) PEA013: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA014', 4, 7) PEA014: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA016', 4, 12) PEA016: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA017', 4, 10) PEA017: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA018', 4, 4) PEA018: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA019', 4, 16) PEA019: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA020', 4, 18) PEA020: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA021', 4, 19) PEA021: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA022', 4, 8) PEA022: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA023', 4, 2) PEA023: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA024', 4, 19) PEA024: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA025', 4, 9) PEA025: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA026', 4, 2) PEA026: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA027', 4, 13) PEA027: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA028', 4, 19) PEA028: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA029', 4, 15) PEA029: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA030', 4, 1) PEA030: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA031', 4, 12) PEA031: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA033', 4, 7) PEA033: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA034', 4, 2) PEA034: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA035', 4, 9) PEA035: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA036', 3, 19) PEA036: won 3 licenses ['N10', 'N11', 'N12']
# ('PEA037', 4, 1) PEA037: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA040', 4, 4) PEA040: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA041', 4, 20) PEA041: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA042', 4, 13) PEA042: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA043', 4, 13) PEA043: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA044', 4, 19) PEA044: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA045', 4, 7) PEA045: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA046', 4, 16) PEA046: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA047', 4, 4) PEA047: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA048', 4, 6) PEA048: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA049', 4, 8) PEA049: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA050', 4, 12) PEA050: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA051', 4, 8) PEA051: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA052', 4, 1) PEA052: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA053', 4, 2) PEA053: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA054', 4, 9) PEA054: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA055', 4, 20) PEA055: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA056', 4, 10) PEA056: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA057', 4, 11) PEA057: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA058', 4, 14) PEA058: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA059', 4, 4) PEA059: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA060', 4, 6) PEA060: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA061', 4, 4) PEA061: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA062', 4, 0) PEA062: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA063', 4, 16) PEA063: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA064', 4, 18) PEA064: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA065', 4, 20) PEA065: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA066', 4, 16) PEA066: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA067', 4, 7) PEA067: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA068', 4, 6) PEA068: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA069', 4, 8) PEA069: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA070', 4, 6) PEA070: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA071', 3, 2) PEA071: won 3 licenses ['M3', 'M4', 'M5']
# ('PEA072', 4, 7) PEA072: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA073', 4, 19) PEA073: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA074', 4, 8) PEA074: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA075', 4, 9) PEA075: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA076', 4, 9) PEA076: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA077', 4, 20) PEA077: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA078', 4, 12) PEA078: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA079', 4, 16) PEA079: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA080', 4, 15) PEA080: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA081', 4, 9) PEA081: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA082', 4, 17) PEA082: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA083', 4, 8) PEA083: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA084', 4, 11) PEA084: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA085', 4, 7) PEA085: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA086', 2, 20) PEA086: won 2 licenses ['N11', 'N12']
# ('PEA087', 4, 3) PEA087: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA088', 4, 16) PEA088: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA089', 4, 17) PEA089: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA090', 4, 5) PEA090: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA091', 4, 3) PEA091: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA092', 4, 11) PEA092: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA093', 4, 20) PEA093: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA094', 4, 14) PEA094: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA095', 4, 14) PEA095: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA096', 3, 18) PEA096: won 3 licenses ['N9', 'N10', 'N11']
# ('PEA097', 4, 6) PEA097: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA098', 4, 19) PEA098: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA099', 4, 5) PEA099: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA100', 4, 20) PEA100: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA101', 4, 2) PEA101: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA102', 4, 7) PEA102: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA103', 4, 17) PEA103: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA104', 4, 11) PEA104: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA105', 4, 20) PEA105: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA106', 4, 15) PEA106: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA107', 4, 20) PEA107: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA108', 4, 16) PEA108: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA109', 4, 3) PEA109: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA110', 4, 5) PEA110: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA111', 4, 4) PEA111: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA112', 4, 17) PEA112: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA113', 4, 11) PEA113: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA115', 4, 3) PEA115: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA116', 4, 19) PEA116: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA117', 4, 16) PEA117: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA118', 4, 11) PEA118: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA119', 4, 19) PEA119: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA120', 4, 14) PEA120: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA121', 4, 20) PEA121: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA122', 4, 20) PEA122: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA123', 4, 4) PEA123: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA124', 4, 8) PEA124: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA125', 4, 16) PEA125: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA126', 4, 7) PEA126: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA127', 4, 5) PEA127: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA128', 4, 3) PEA128: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA129', 4, 3) PEA129: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA130', 4, 17) PEA130: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA131', 4, 12) PEA131: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA132', 4, 15) PEA132: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA133', 4, 0) PEA133: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA134', 4, 11) PEA134: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA135', 4, 2) PEA135: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA136', 4, 1) PEA136: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA137', 4, 12) PEA137: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA138', 4, 0) PEA138: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA139', 4, 8) PEA139: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA140', 4, 9) PEA140: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA141', 4, 5) PEA141: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA142', 4, 6) PEA142: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA143', 4, 16) PEA143: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA144', 4, 11) PEA144: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA145', 4, 13) PEA145: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA146', 3, 12) PEA146: won 3 licenses ['N3', 'N4', 'N5']
# ('PEA147', 4, 13) PEA147: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA148', 4, 18) PEA148: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA149', 4, 15) PEA149: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA150', 4, 0) PEA150: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA151', 4, 3) PEA151: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA152', 4, 16) PEA152: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA153', 4, 7) PEA153: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA154', 4, 0) PEA154: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA155', 4, 0) PEA155: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA156', 4, 0) PEA156: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA157', 4, 0) PEA157: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA158', 4, 11) PEA158: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA159', 4, 9) PEA159: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA160', 4, 5) PEA160: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA161', 4, 19) PEA161: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA162', 4, 6) PEA162: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA163', 4, 11) PEA163: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA164', 4, 16) PEA164: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA165', 4, 15) PEA165: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA166', 4, 14) PEA166: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA167', 4, 0) PEA167: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA168', 4, 19) PEA168: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA169', 4, 4) PEA169: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA170', 4, 6) PEA170: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA171', 4, 12) PEA171: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA172', 4, 17) PEA172: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA173', 4, 0) PEA173: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA174', 4, 13) PEA174: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA175', 4, 11) PEA175: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA177', 4, 20) PEA177: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA178', 4, 5) PEA178: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA179', 4, 17) PEA179: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA180', 4, 20) PEA180: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA181', 4, 2) PEA181: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA182', 4, 14) PEA182: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA183', 4, 3) PEA183: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA184', 4, 8) PEA184: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA185', 4, 14) PEA185: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA186', 4, 13) PEA186: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA187', 4, 1) PEA187: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA188', 4, 7) PEA188: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA189', 4, 19) PEA189: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA190', 4, 8) PEA190: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA191', 4, 20) PEA191: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA192', 4, 0) PEA192: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA193', 4, 20) PEA193: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA194', 4, 20) PEA194: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA195', 4, 12) PEA195: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA196', 4, 15) PEA196: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA197', 4, 16) PEA197: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA198', 4, 3) PEA198: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA199', 4, 17) PEA199: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA200', 4, 8) PEA200: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA201', 4, 10) PEA201: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA202', 4, 0) PEA202: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA203', 4, 6) PEA203: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA204', 4, 15) PEA204: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA205', 4, 20) PEA205: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA206', 4, 4) PEA206: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA207', 4, 20) PEA207: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA208', 4, 11) PEA208: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA209', 4, 5) PEA209: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA210', 4, 20) PEA210: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA211', 4, 4) PEA211: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA212', 4, 14) PEA212: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA213', 4, 17) PEA213: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA215', 4, 5) PEA215: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA216', 4, 3) PEA216: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA217', 4, 19) PEA217: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA218', 4, 12) PEA218: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA219', 4, 0) PEA219: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA220', 4, 19) PEA220: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA221', 4, 16) PEA221: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA222', 4, 14) PEA222: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA223', 4, 15) PEA223: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA224', 4, 0) PEA224: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA225', 4, 11) PEA225: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA226', 4, 20) PEA226: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA227', 4, 9) PEA227: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA228', 4, 6) PEA228: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA229', 4, 2) PEA229: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA230', 4, 1) PEA230: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA231', 4, 7) PEA231: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA232', 4, 14) PEA232: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA233', 4, 6) PEA233: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA234', 4, 4) PEA234: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA235', 4, 20) PEA235: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA236', 4, 13) PEA236: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA237', 4, 20) PEA237: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA238', 4, 16) PEA238: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA239', 4, 3) PEA239: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA240', 4, 6) PEA240: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA241', 4, 2) PEA241: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA242', 4, 5) PEA242: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA243', 4, 12) PEA243: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA244', 4, 7) PEA244: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA245', 4, 14) PEA245: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA246', 4, 0) PEA246: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA247', 4, 14) PEA247: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA248', 4, 0) PEA248: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA249', 4, 4) PEA249: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA250', 4, 7) PEA250: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA251', 4, 5) PEA251: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA252', 4, 11) PEA252: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA253', 4, 5) PEA253: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA254', 4, 20) PEA254: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA255', 4, 6) PEA255: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA256', 4, 1) PEA256: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA257', 4, 8) PEA257: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA258', 4, 20) PEA258: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA259', 4, 3) PEA259: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA260', 4, 1) PEA260: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA261', 4, 9) PEA261: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA262', 4, 10) PEA262: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA263', 4, 5) PEA263: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA264', 4, 10) PEA264: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA265', 4, 6) PEA265: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA266', 4, 11) PEA266: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA268', 4, 9) PEA268: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA269', 4, 4) PEA269: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA270', 4, 7) PEA270: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA271', 4, 2) PEA271: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA272', 4, 6) PEA272: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA273', 4, 6) PEA273: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA274', 4, 9) PEA274: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA275', 4, 8) PEA275: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA276', 4, 4) PEA276: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA278', 4, 0) PEA278: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA279', 4, 0) PEA279: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA280', 4, 1) PEA280: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA282', 4, 17) PEA282: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA283', 4, 5) PEA283: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA284', 4, 3) PEA284: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA285', 4, 1) PEA285: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA286', 4, 20) PEA286: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA287', 4, 19) PEA287: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA288', 4, 0) PEA288: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA289', 4, 9) PEA289: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA290', 4, 17) PEA290: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA291', 4, 8) PEA291: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA292', 4, 0) PEA292: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA293', 4, 0) PEA293: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA294', 4, 18) PEA294: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA295', 3, 13) PEA295: won 3 licenses ['N4', 'N5', 'N6']
# ('PEA296', 4, 0) PEA296: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA297', 4, 18) PEA297: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA298', 4, 16) PEA298: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA299', 4, 3) PEA299: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA300', 4, 8) PEA300: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA301', 4, 7) PEA301: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA302', 4, 17) PEA302: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA303', 4, 3) PEA303: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA304', 4, 5) PEA304: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA305', 4, 10) PEA305: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA306', 4, 6) PEA306: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA307', 4, 0) PEA307: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA308', 4, 20) PEA308: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA309', 4, 9) PEA309: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA310', 4, 14) PEA310: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA311', 4, 10) PEA311: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA312', 4, 12) PEA312: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA313', 4, 20) PEA313: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA314', 4, 16) PEA314: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA315', 4, 13) PEA315: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA316', 4, 20) PEA316: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA317', 4, 5) PEA317: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA318', 4, 0) PEA318: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA319', 4, 11) PEA319: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA320', 4, 18) PEA320: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA321', 4, 1) PEA321: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA322', 4, 8) PEA322: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA323', 4, 6) PEA323: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA324', 4, 19) PEA324: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA325', 4, 15) PEA325: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA326', 4, 19) PEA326: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA327', 4, 7) PEA327: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA328', 4, 19) PEA328: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA329', 4, 2) PEA329: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA330', 4, 8) PEA330: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA331', 4, 20) PEA331: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA332', 4, 2) PEA332: won 4 licenses ['M3', 'M4', 'M5', 'M6']
# ('PEA333', 4, 16) PEA333: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA334', 4, 3) PEA334: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA335', 4, 17) PEA335: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA336', 4, 18) PEA336: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA337', 4, 9) PEA337: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA338', 4, 3) PEA338: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA339', 4, 11) PEA339: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA340', 4, 19) PEA340: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA341', 4, 12) PEA341: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA342', 4, 14) PEA342: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA343', 4, 3) PEA343: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA344', 4, 10) PEA344: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA345', 4, 4) PEA345: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA346', 4, 11) PEA346: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA347', 4, 20) PEA347: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA348', 4, 11) PEA348: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA349', 4, 12) PEA349: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA350', 4, 20) PEA350: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA351', 4, 1) PEA351: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA352', 4, 15) PEA352: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA353', 4, 18) PEA353: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA355', 4, 6) PEA355: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA356', 4, 20) PEA356: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA357', 4, 4) PEA357: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA358', 4, 7) PEA358: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA359', 4, 11) PEA359: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA360', 4, 16) PEA360: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA361', 4, 18) PEA361: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA362', 4, 17) PEA362: won 4 licenses ['N8', 'N9', 'N10', 'N11']
# ('PEA363', 4, 9) PEA363: won 4 licenses ['M10', 'N1', 'N2', 'N3']
# ('PEA364', 4, 18) PEA364: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA365', 4, 18) PEA365: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA366', 4, 13) PEA366: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA368', 4, 8) PEA368: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA369', 4, 12) PEA369: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA370', 4, 10) PEA370: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA371', 4, 10) PEA371: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA372', 4, 5) PEA372: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA373', 4, 19) PEA373: won 4 licenses ['N10', 'N11', 'N12', 'N13']
# ('PEA374', 4, 14) PEA374: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA375', 4, 13) PEA375: won 4 licenses ['N4', 'N5', 'N6', 'N7']
# ('PEA377', 4, 7) PEA377: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA378', 4, 20) PEA378: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA379', 4, 5) PEA379: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# ('PEA380', 4, 10) PEA380: won 4 licenses ['N1', 'N2', 'N3', 'N4']
# ('PEA381', 4, 14) PEA381: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA382', 4, 1) PEA382: won 4 licenses ['M2', 'M3', 'M4', 'M5']
# ('PEA385', 4, 11) PEA385: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA386', 4, 14) PEA386: won 4 licenses ['N5', 'N6', 'N7', 'N8']
# ('PEA387', 4, 7) PEA387: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA389', 4, 4) PEA389: won 4 licenses ['M5', 'M6', 'M7', 'M8']
# ('PEA390', 4, 6) PEA390: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA391', 4, 8) PEA391: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA392', 2, 20) PEA392: won 2 licenses ['N11', 'N12']
# ('PEA394', 4, 3) PEA394: won 4 licenses ['M4', 'M5', 'M6', 'M7']
# ('PEA395', 4, 12) PEA395: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA396', 4, 20) PEA396: won 4 licenses ['N11', 'N12', 'N13', 'N14']
# ('PEA397', 4, 0) PEA397: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA398', 4, 12) PEA398: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA399', 4, 16) PEA399: won 4 licenses ['N7', 'N8', 'N9', 'N10']
# ('PEA401', 4, 12) PEA401: won 4 licenses ['N3', 'N4', 'N5', 'N6']
# ('PEA402', 4, 7) PEA402: won 4 licenses ['M8', 'M9', 'M10', 'N1']
# ('PEA403', 4, 0) PEA403: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA404', 4, 0) PEA404: won 4 licenses ['M1', 'M2', 'M3', 'M4']
# ('PEA405', 4, 15) PEA405: won 4 licenses ['N6', 'N7', 'N8', 'N9']
# ('PEA406', 4, 11) PEA406: won 4 licenses ['N2', 'N3', 'N4', 'N5']
# ('PEA407', 4, 18) PEA407: won 4 licenses ['N9', 'N10', 'N11', 'N12']
# ('PEA408', 4, 6) PEA408: won 4 licenses ['M7', 'M8', 'M9', 'M10']
# ('PEA409', 4, 8) PEA409: won 4 licenses ['M9', 'M10', 'N1', 'N2']
# ('PEA410', 4, 5) PEA410: won 4 licenses ['M6', 'M7', 'M8', 'M9']
# Total Spent = 99997505
